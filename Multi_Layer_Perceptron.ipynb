# %% [markdown]
# <a href="https://colab.research.google.com/github/evanlin917/Multi-Layer-Perceptron/blob/main/Multi_Layer_Perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import sklearn

#creating an artificial dataset using scikit-learn
from sklearn.datasets import make_classification
x, y = make_classification(n_features = 2, n_redundant = 0, n_informative = 2, random_state = 3)
plt.scatter(x[y == 0][:, 0], x[y == 0][:, 1], s = 100, edgecolors = 'k')
plt.scatter(x[y == 1][:, 0], x[y == 1][:, 1], s = 100, edgecolors = 'k', marker = '^')
plt.show()

#creating a multi-layer perceptron model to train against the artificially created data set
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 3)
mlp = MLPClassifier(max_iter = 1000)
mlp.fit(x_train, y_train)
print("accuracy: ", mlp.score(x_test, y_test))
# Out:
# accuracy:  0.64
